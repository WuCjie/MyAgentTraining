# %% [markdown]
# ## 1、学习使用调用大模型api

# %%
import dotenv
from langchain_openai import ChatOpenAI
import os
import time

# 加载环境变量
dotenv.load_dotenv()

# 设置API配置（变量名要和.env文件里的一致）
os.environ['OPENAI_API_KEY'] = os.getenv("OPENAI_API_KEY")
os.environ['OPENAI_BASE_URL'] = os.getenv("OPENAI_BASE_URL")

# 创建大模型实例
llm = ChatOpenAI(model="gpt-4o-mini")

# 记录开始时间
start_time = time.time()

# 调用模型
prompt = "什么是大模型？"
response = llm.invoke(prompt)

# 计算耗时
elapsed_time = time.time() - start_time

# 打印结果
print(f"问题: {prompt}")
print(f"回答: {response.content}")
print(f"输入Token: {response.usage_metadata['input_tokens']}")
print(f"输出Token: {response.usage_metadata['output_tokens']}")
print(f"总Token: {response.usage_metadata['total_tokens']}")
print(f"耗时: {elapsed_time:.2f}秒")
# Out:
# 问题: 什么是大模型？
# 回答: 大模型通常是指参数量非常庞大的机器学习模型，尤其是在深度学习领域。这些模型通过使用海量的数据进行训练，从而能够捕捉复杂的模式和特征。大模型常常包括数亿至数千亿个参数，能够在如自然语言处理（NLP）、计算机视觉等任务上表现出色。
#
# 大模型的特点包括：
#
# 1. **高容量**：由于参数量大，它们能够更好地拟合复杂的数据分布。
# 2. **预训练和微调**：大多数大模型采用预训练策略，先在大规模数据集上训练，然后在特定任务上进行微调。
# 3. **多任务能力**：一些大模型可以同时处理多个相关任务，提高了模型的通用性。
# 4. **需要大量计算资源**：训练和推理过程中通常需要强大的计算资源和存储能力。
#
# 近年来，像GPT、BERT、DALL-E等大模型在各自的领域中取得了显著的成果，并推动了人工智能的发展。
# 输入Token: 12
# 输出Token: 229
# 总Token: 241
# 耗时: 4.50秒
